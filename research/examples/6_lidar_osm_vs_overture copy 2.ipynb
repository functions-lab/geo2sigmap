# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
import scene_generation.core as core_mod
import time

from pathlib import Path
from scene_generation.core import Scene
from scene_generation.utils import rect_from_point_and_size
from collections import Counter
from matplotlib.patches import Patch
from PIL import Image, ImageDraw
from sionna.rt import scene, preview

# %%
# Scene center (only need to update CENTER_LON, CENTER_LAT, DATA_DIR_LIDAR_OSM, DATA_DIR_OVERTURE and run the rest of the cells to receive full analysis)
# DuPont Circle: -77.043446, 38.909647
# Duke Wilkinson area: -78.940297, 36.002556
# Flatiron Building: -73.9897, 40.7411
CENTER_LON = -74.0059413
CENTER_LAT  = 40.7127837

SCENE_WIDTH  = 500   # east–west extent, metres
SCENE_HEIGHT = 500   # north–south extent, metres

DATA_DIR_LIDAR_OSM = "./scenes/losang_example_lidar_osm"
DATA_DIR_OVERTURE = "./scenes/losang_example_overture"

OSM_SERVER = "http://10.237.198.210:3452/api/interpreter"

# %%
for out_dir in (DATA_DIR_LIDAR_OSM, DATA_DIR_OVERTURE):
    os.makedirs(out_dir, exist_ok=True)
    print(f"Output directory: {os.path.abspath(out_dir)}")
# Out:
# Output directory: /home/rt279/geo2sigmap-fork/research/examples/scenes/losang_example_lidar_osm
# Output directory: /home/rt279/geo2sigmap-fork/research/examples/scenes/losang_example_overture

# %%
def summarize_height_sources(mode, height_sources):
    """Summarize counts and percentages of buildings by selected height source."""
    total_buildings = sum(height_sources.values())
    rows = []

    for source, building_count in height_sources.most_common():
        building_percentage = (
            (building_count / total_buildings) * 100 if total_buildings else 0.0
        )
        rows.append(
            {
                "mode": mode,
                "height_source": source,
                "building_count": building_count,
                "building_percentage": f"{building_percentage:.2f}%",
            }
        )

    return pd.DataFrame(
        rows,
        columns=["mode", "height_source", "building_count", "building_percentage"],
    )


def iter_polygons(geometry):
    """Yield polygon parts from a Shapely Polygon or MultiPolygon."""
    if geometry is None or geometry.is_empty:
        return

    if geometry.geom_type == "Polygon":
        yield geometry
    elif geometry.geom_type == "MultiPolygon":
        yield from geometry.geoms


def plot_height_source_footprints(
    lidar_records, overture_records, *, figsize=(14, 7), alpha=0.75
):
    """Plot building footprints for both modes, colored by height source."""
    mode_records = [
        ("lidar-osm", lidar_records),
        ("overture", overture_records),
    ]
    all_sources = sorted(
        {
            record["height_source"]
            for _, records in mode_records
            for record in records
        }
    )
    cmap = plt.get_cmap("tab10")
    source_colors = {
        source: cmap(index % cmap.N) for index, source in enumerate(all_sources)
    }

    fig, axes = plt.subplots(1, 2, figsize=figsize, constrained_layout=True)
    for ax, (mode, records) in zip(axes, mode_records):
        for record in records:
            source = record["height_source"]
            for polygon in iter_polygons(record["footprint"]):
                x, y = polygon.exterior.xy
                ax.fill(
                    x,
                    y,
                    facecolor=source_colors[source],
                    edgecolor="black",
                    linewidth=0.2,
                    alpha=alpha,
                )
                for interior in polygon.interiors:
                    hole_x, hole_y = interior.xy
                    ax.fill(
                        hole_x,
                        hole_y,
                        facecolor="white",
                        edgecolor="black",
                        linewidth=0.2,
                    )

        ax.set_title(f"{mode} ({len(records)} buildings)")
        ax.set_aspect("equal", adjustable="box")
        ax.axis("off")

    legend_handles = [
        Patch(facecolor=color, edgecolor="black", label=source)
        for source, color in source_colors.items()
    ]
    fig.legend(
        handles=legend_handles,
        loc="lower center",
        ncol=max(1, min(4, len(legend_handles))),
    )
    return fig, axes


def rasterize_height_source_mask(records, height_source, shape, ground_bounds):
    """Rasterize footprints for one height source onto a building-map grid."""
    min_x, _, _, max_y = ground_bounds
    mask_image = Image.new("1", (shape[1], shape[0]), 0)
    draw = ImageDraw.Draw(mask_image)

    for record in records:
        if record["height_source"] != height_source:
            continue

        for polygon in iter_polygons(record["footprint"]):
            pixel_coords = [(x - min_x, max_y - y) for x, y in polygon.exterior.coords]
            draw.polygon(pixel_coords, outline=1, fill=1)

    return np.array(mask_image, dtype=bool)


def generate_scene(mode, out_dir, *, track_height_sources=False):
    """Generate the scene and optionally count selected height sources."""
    scene_polygon = rect_from_point_and_size(
    CENTER_LON, CENTER_LAT, "center", SCENE_WIDTH, SCENE_HEIGHT
    )

    height_sources = []
    height_source_records = []
    original_resolve = core_mod.resolve_building_height

    def logging_resolve_building_height(*args, **kwargs):
        kwargs = dict(kwargs)
        kwargs["return_source"] = True
        height, metadata = original_resolve(*args, **kwargs)
        source = metadata.get("source", "unknown")
        footprint = args[1] if len(args) > 1 else kwargs.get("building_polygon")
        height_sources.append(source)
        height_source_records.append(
            {
                "mode": mode,
                "height_source": source,
                "height_m": height,
                "footprint": footprint,
            }
        )
        return height

    if track_height_sources:
        core_mod.resolve_building_height = logging_resolve_building_height

    try:
        scene = Scene()
        building_height_map = scene(
            points=scene_polygon,
            data_dir=out_dir,
            osm_server_addr=OSM_SERVER,
            hag_tiff_path=None,  # None lets lidar-osm create/reuse out_dir/test_hag.tif
            ground_material_type="mat-itu_wet_ground",
            rooftop_material_type="mat-itu_metal",
            wall_material_type="mat-itu_concrete",
            generate_building_map=True,
            building_height_mode=mode,
            # lidar_terrain=False,
            # dem_terrain=False,
        )
        ground_bounds = scene._ground_polygon_envelope_UTM.bounds
    finally:
        if track_height_sources:
            core_mod.resolve_building_height = original_resolve

    return building_height_map, Counter(height_sources), height_source_records, ground_bounds

scene_generation_runtimes = []

start_time = time.perf_counter()
lidar_height_map, lidar_height_sources, lidar_height_source_records, lidar_ground_bounds = generate_scene(
    "lidar-osm", DATA_DIR_LIDAR_OSM, track_height_sources=True
)
scene_generation_runtimes.append(
    {"mode": "lidar-osm", "runtime_seconds": time.perf_counter() - start_time}
)

start_time = time.perf_counter()
overture_height_map, overture_height_sources, overture_height_source_records, overture_ground_bounds = generate_scene(
    "overture", DATA_DIR_OVERTURE, track_height_sources=True
)
scene_generation_runtimes.append(
    {"mode": "overture", "runtime_seconds": time.perf_counter() - start_time}
)

print("Scene generation complete!")
scene_generation_runtime_summary = pd.DataFrame(scene_generation_runtimes)
lidar_runtime_seconds = scene_generation_runtime_summary.loc[
    scene_generation_runtime_summary["mode"] == "lidar-osm",
    "runtime_seconds",
].iloc[0]
scene_generation_runtime_summary["runtime_seconds"] = scene_generation_runtime_summary[
    "runtime_seconds"
].round(3)
scene_generation_runtime_summary["relative_to_lidar_osm"] = (
    scene_generation_runtime_summary["runtime_seconds"] / lidar_runtime_seconds
).round(2)
display(scene_generation_runtime_summary)

height_source_summary = pd.concat(
    [
        summarize_height_sources("lidar-osm", lidar_height_sources),
        summarize_height_sources("overture", overture_height_sources),
    ],
    ignore_index=True,
)
display(height_source_summary)
plot_height_source_footprints(lidar_height_source_records, overture_height_source_records)
plt.show()
print("LiDAR HAG raster exists :", (Path(DATA_DIR_LIDAR_OSM) / "test_hag.tif").exists())
# Out:
# Parsing buildings: 100%|██████████| 156/156 [00:01<00:00, 94.94it/s]
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Parsing buildings:  25%|██▍       | 74/300 [00:00<00:00, 351.38it/s]Building part f76ae995-f55a-321f-bc0b-700e563d160e top height 44.00 exceeds parent building d058153b-c5a7-40f7-a4b6-36005c9bd49c top height 40.00; treating min_height/min_floor as 0 for the part
# Parsing buildings:  41%|████▏     | 124/300 [00:00<00:00, 414.54it/s]Building part e89a56ec-3ddb-326b-8fea-50f9608350a1 top height 74.50 exceeds parent building f8437dfe-0b14-4e58-96bb-bba278fe1163 top height 22.63; treating min_height/min_floor as 0 for the part
# Building part 15b51636-fe89-3345-9336-1e84a5664971 top height 98.50 exceeds parent building c1298716-7c0f-420d-bc21-36eb92ebe185 top height 35.00; treating min_height/min_floor as 0 for the part
# Building part d0bf1fb1-7844-3faa-adba-e349d3e7f027 top height 55.00 exceeds parent building f40050c5-ff92-401f-8570-633169e52a92 top height 22.38; treating min_height/min_floor as 0 for the part
# Building part 16d6ddf4-e4ec-3ffa-b9f4-94a915886b36 top height 37.00 exceeds parent building f40050c5-ff92-401f-8570-633169e52a92 top height 22.38; treating min_height/min_floor as 0 for the part
# Building part c9d4f706-7ea7-3a93-b059-b5e19f3b4f3d top height 85.00 exceeds parent building f40050c5-ff92-401f-8570-633169e52a92 top height 22.38; treating min_height/min_floor as 0 for the part
# Building part 78ec25a7-ce98-33fc-9154-6b04d817e78f top height 90.00 exceeds parent building b6b4301a-2b8c-466b-900a-9df4dad5b95b top height 58.40; treating min_height/min_floor as 0 for the part
# Building part 371d7748-e350-372f-9bef-88a32f301741 top height 103.00 exceeds parent building b6b4301a-2b8c-466b-900a-9df4dad5b95b top height 58.40; treating min_height/min_floor as 0 for the part
# Building part c82863e0-107a-3278-8090-48c6129e55ee top height 117.30 exceeds parent building 58f20597-c7bf-490b-8e86-5334a57f2d5b top height 104.00; treating min_height/min_floor as 0 for the part
# Building part a824868b-bf50-3e4a-b418-b7c80dbebc73 top height 25.90 exceeds parent building f8253acb-27fc-4c11-843a-f46f328af435 top height 13.00; treating min_height/min_floor as 0 for the part
# Building part f28340d4-5997-3626-9f9d-0cfaebfc1e6d top height 46.00 exceeds parent building a38dc59a-1fb7-4ca1-9932-b34baab057c7 top height 42.00; treating min_height/min_floor as 0 for the part
# Building part c2e7d561-22dd-3b7b-af7b-133f93a83994 top height 17.00 exceeds parent building af72425d-8a0d-4a9b-8ec4-04f5da6374ac top height 14.00; treating min_height/min_floor as 0 for the part
# Building part 749efe0b-0d20-3d74-97e4-f284fff64200 top height 43.00 exceeds parent building f40050c5-ff92-401f-8570-633169e52a92 top height 22.38; treating min_height/min_floor as 0 for the part
# Building part 8932bae3-5d74-3b95-a61b-25010d9e950d top height 55.00 exceeds parent building f40050c5-ff92-401f-8570-633169e52a92 top height 22.38; treating min_height/min_floor as 0 for the part
# Building part 8bad1a8f-0128-3f2a-b9d0-f2471ddfefd2 top height 37.00 exceeds parent building f40050c5-ff92-401f-8570-633169e52a92 top height 22.38; treating min_height/min_floor as 0 for the part
# Building part eb94f0e8-71e9-38a3-a290-473c3e818e1f top height 80.00 exceeds parent building f40050c5-ff92-401f-8570-633169e52a92 top height 22.38; treating min_height/min_floor as 0 for the part
# Building part a73ef775-60c4-31dd-8a26-1e7c38eb199f top height 67.00 exceeds parent building f40050c5-ff92-401f-8570-633169e52a92 top height 22.38; treating min_height/min_floor as 0 for the part
# Building part ddf2438d-3be6-31b5-b547-668448f3e798 top height 73.00 exceeds parent building f40050c5-ff92-401f-8570-633169e52a92 top height 22.38; treating min_height/min_floor as 0 for the part
# Building part 835ecc31-c4cd-31e0-820f-5260a73d5967 top height 55.00 exceeds parent building f40050c5-ff92-401f-8570-633169e52a92 top height 22.38; treating min_height/min_floor as 0 for the part
# Building part 7d9f77e1-c80f-3b16-99f2-d09e1620bbab top height 119.00 exceeds parent building f40050c5-ff92-401f-8570-633169e52a92 top height 22.38; treating min_height/min_floor as 0 for the part
# Building part b049409e-c8fb-374e-aace-27ebe21edd1c top height 119.00 exceeds parent building f40050c5-ff92-401f-8570-633169e52a92 top height 22.38; treating min_height/min_floor as 0 for the part
# Building part 47849e49-2bb5-3855-af7a-9a265fd4074b top height 70.00 exceeds parent building f40050c5-ff92-401f-8570-633169e52a92 top height 22.38; treating min_height/min_floor as 0 for the part
# Parsing buildings:  56%|█████▌    | 167/300 [00:00<00:00, 417.65it/s]Building part 862def78-aff9-3d06-b498-79b80af6f507 top height 55.00 exceeds parent building f40050c5-ff92-401f-8570-633169e52a92 top height 22.38; treating min_height/min_floor as 0 for the part
# Building part 4908713e-97f1-3ac3-835d-7d5f7f70a025 top height 87.00 exceeds parent building 7dc65ebf-6239-4260-bc93-8357539027e8 top height 75.00; treating min_height/min_floor as 0 for the part
# Building part 300cea66-5283-3bb6-b8e5-581c4ed21c6d top height 118.00 exceeds parent building fca1b00e-a0e9-41a0-9e7b-56e4ec867461 top height 113.40; treating min_height/min_floor as 0 for the part
# Parsing buildings:  70%|██████▉   | 209/300 [00:00<00:00, 376.66it/s]Building part f6bfb02d-4163-31fe-80a2-ff43ea756a02 top height 113.00 exceeds parent building c0ef0dca-ffda-4263-a9a6-1ec8885f932b top height 110.20; treating min_height/min_floor as 0 for the part
# Building part f87d07ec-7833-3135-b847-1b0f8165b6f3 top height 165.00 exceeds parent building b595926c-7542-493e-b15a-a4e97b2e1c1e top height 21.00; treating min_height/min_floor as 0 for the part
# Building part 3272c07a-f439-390d-aa5f-45b39f4f25ad top height 25.00 exceeds parent building 9902bf94-1ec5-4f43-b8e7-a1c78a5ed3e7 top height 18.81; treating min_height/min_floor as 0 for the part
# Building part 5fc0c129-5b7c-3a9e-9049-d0d3cee87468 top height 47.00 exceeds parent building af72425d-8a0d-4a9b-8ec4-04f5da6374ac top height 14.00; treating min_height/min_floor as 0 for the part
# Building part 6789c466-e26d-3b94-958f-981847e1c9cc top height 37.00 exceeds parent building 27101fe2-d767-4d14-b27c-54f6b5d2ff9d top height 36.60; treating min_height/min_floor as 0 for the part
# Building part f1ccba41-a8cb-39ba-b220-04d1afc82f72 top height 37.00 exceeds parent building 530fc384-add1-4f0b-be56-239f0286517a top height 25.00; treating min_height/min_floor as 0 for the part
# Building part b150b1e1-e9b2-3a6c-a1bd-e2d3df6d5a42 top height 37.00 exceeds parent building 530fc384-add1-4f0b-be56-239f0286517a top height 25.00; treating min_height/min_floor as 0 for the part
# Building part 39e668b8-3930-3654-9c77-a052a45d97a0 top height 37.00 exceeds parent building 530fc384-add1-4f0b-be56-239f0286517a top height 25.00; treating min_height/min_floor as 0 for the part
# Building part 08856c16-6a34-3a7a-a0c3-2120df629678 top height 42.00 exceeds parent building 530fc384-add1-4f0b-be56-239f0286517a top height 25.00; treating min_height/min_floor as 0 for the part
# Building part b36df315-ed3b-3739-ba8f-2c9a3b66d383 top height 37.00 exceeds parent building 530fc384-add1-4f0b-be56-239f0286517a top height 25.00; treating min_height/min_floor as 0 for the part
# Building part 546e9a5b-7f9d-3d42-a8ea-95b05bf2b1bf top height 37.00 exceeds parent building 530fc384-add1-4f0b-be56-239f0286517a top height 25.00; treating min_height/min_floor as 0 for the part
# Building part 978ec668-fb55-31e9-8760-218aacdbe4de top height 37.00 exceeds parent building 530fc384-add1-4f0b-be56-239f0286517a top height 25.00; treating min_height/min_floor as 0 for the part
# Building part 35731244-0997-339a-83ab-e26b101a5608 top height 45.00 exceeds parent building 27101fe2-d767-4d14-b27c-54f6b5d2ff9d top height 36.60; treating min_height/min_floor as 0 for the part
# Building part 1e1f0dc3-0c3c-31f3-95e2-aecec64c8954 top height 40.00 exceeds parent building 27101fe2-d767-4d14-b27c-54f6b5d2ff9d top height 36.60; treating min_height/min_floor as 0 for the part
# Building part ed63ca74-999b-32a7-801d-de3b06a74da7 top height 43.60 exceeds parent building 3b6dc3db-ed9b-443d-b01a-b0072e3db908 top height 19.60; treating min_height/min_floor as 0 for the part
# Building part aa85cd34-f59b-3d36-bbff-cfc359c8cf32 top height 42.50 exceeds parent building 530fc384-add1-4f0b-be56-239f0286517a top height 25.00; treating min_height/min_floor as 0 for the part
# Building part 3a324860-5863-3f48-bc46-b1f2d631c3ba top height 42.50 exceeds parent building 530fc384-add1-4f0b-be56-239f0286517a top height 25.00; treating min_height/min_floor as 0 for the part
# Building part 45d54358-c6ce-3163-890e-c0572f1af576 top height 55.10 exceeds parent building 489cd585-2cde-44b2-b5bc-1f9add534f6e top height 34.10; treating min_height/min_floor as 0 for the part
# Building part a8d8e2c4-c2c5-3cc4-b7d2-a00d74161a31 top height 64.00 exceeds parent building 489cd585-2cde-44b2-b5bc-1f9add534f6e top height 34.10; treating min_height/min_floor as 0 for the part
# Parsing buildings:  84%|████████▍ | 252/300 [00:00<00:00, 390.57it/s]Building part ff9aefbb-31e5-33bc-af41-27fa2fd5aa64 top height 58.20 exceeds parent building 489cd585-2cde-44b2-b5bc-1f9add534f6e top height 34.10; treating min_height/min_floor as 0 for the part
# Building part 4df188dd-3870-3a97-800e-4da43594f5ee top height 50.00 exceeds parent building 8af3c625-8969-438b-97ef-3195e7c0ad28 top height 23.00; treating min_height/min_floor as 0 for the part
# Building part 4234f684-b560-37c8-b352-9734cdcdc9cf top height 49.00 exceeds parent building 8af3c625-8969-438b-97ef-3195e7c0ad28 top height 23.00; treating min_height/min_floor as 0 for the part
# Building part c313a943-4fc2-3af6-aec1-ab9ba09e4aaa top height 54.00 exceeds parent building 27101fe2-d767-4d14-b27c-54f6b5d2ff9d top height 36.60; treating min_height/min_floor as 0 for the part
# Building part af9bb691-1d81-3416-adca-0fe16485383e top height 57.50 exceeds parent building 27101fe2-d767-4d14-b27c-54f6b5d2ff9d top height 36.60; treating min_height/min_floor as 0 for the part
# Building part b084bdce-f85b-3498-8a74-16bd2c69e515 top height 59.50 exceeds parent building 27101fe2-d767-4d14-b27c-54f6b5d2ff9d top height 36.60; treating min_height/min_floor as 0 for the part
# Building part 02a63ece-17f1-3015-84cf-944a91733a2a top height 74.20 exceeds parent building fbc14777-a221-4ec6-bed8-44afd39165ea top height 48.00; treating min_height/min_floor as 0 for the part
# Building part 999f89f7-ece9-3f4e-bed1-379e28b1166b top height 74.20 exceeds parent building fbc14777-a221-4ec6-bed8-44afd39165ea top height 48.00; treating min_height/min_floor as 0 for the part
# Building part 25380c3c-789b-3ed0-add3-b57cf9a3b0af top height 93.20 exceeds parent building a38dc59a-1fb7-4ca1-9932-b34baab057c7 top height 42.00; treating min_height/min_floor as 0 for the part
# Building part c85132b3-45df-35c4-938b-3a93727cd98f top height 97.20 exceeds parent building a38dc59a-1fb7-4ca1-9932-b34baab057c7 top height 42.00; treating min_height/min_floor as 0 for the part
# Building part 24694cd1-9e1d-36ab-a992-f6a28115d60d top height 104.90 exceeds parent building c9789d12-38dc-4277-b562-c84cbaa1cdaf top height 50.90; treating min_height/min_floor as 0 for the part
# Building part 63387cda-e4b2-3694-8c12-53eb8d712569 top height 104.90 exceeds parent building c9789d12-38dc-4277-b562-c84cbaa1cdaf top height 50.90; treating min_height/min_floor as 0 for the part
# Building part f118a477-a657-31df-8a35-935a916933ec top height 153.00 exceeds parent building e1a1e419-e413-49b9-8012-973fc8051342 top height 68.00; treating min_height/min_floor as 0 for the part
# Building part b59d0363-3a01-3a28-af89-724035c434aa top height 180.00 exceeds parent building 7dc65ebf-6239-4260-bc93-8357539027e8 top height 75.00; treating min_height/min_floor as 0 for the part
# Building part 5c3b7899-8a2a-3edc-bd8b-c4ab34182745 top height 198.00 exceeds parent building 7dc65ebf-6239-4260-bc93-8357539027e8 top height 75.00; treating min_height/min_floor as 0 for the part
# Building part f58551c7-d139-3373-a9e8-917ff942b271 top height 255.00 exceeds parent building 7dc65ebf-6239-4260-bc93-8357539027e8 top height 75.00; treating min_height/min_floor as 0 for the part
# Building part 51d0b573-8b3f-3229-bbbc-59a0b49a22ee top height 230.00 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Building part 9e3d9f57-486f-39aa-ad6e-0871c985bf9d top height 220.00 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Building part b019e3a3-e127-3cb8-bf7b-f9c783b69ee8 top height 220.00 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Building part 050d5e7b-506b-35c6-8193-c551df3a2a19 top height 232.00 exceeds parent building c0ef0dca-ffda-4263-a9a6-1ec8885f932b top height 110.20; treating min_height/min_floor as 0 for the part
# Building part 2b3c894d-1100-37ea-854c-d9857d49d3c3 top height 229.00 exceeds parent building c0ef0dca-ffda-4263-a9a6-1ec8885f932b top height 110.20; treating min_height/min_floor as 0 for the part
# Building part d8309a12-460c-3b45-bdb4-0ced5f4317cc top height 241.00 exceeds parent building c0ef0dca-ffda-4263-a9a6-1ec8885f932b top height 110.20; treating min_height/min_floor as 0 for the part
# Building part ea5ac94c-8782-3197-8623-9274b158e3da top height 295.00 exceeds parent building a8c95904-bfb7-4e8e-875c-b3d9d2a93d84 top height 120.00; treating min_height/min_floor as 0 for the part
# Building part da30c462-bae4-3a20-8947-d7cca2e7009b top height 290.00 exceeds parent building a8c95904-bfb7-4e8e-875c-b3d9d2a93d84 top height 120.00; treating min_height/min_floor as 0 for the part
# Building part d0f8326a-970f-3dd5-bc52-2704ee1f242a top height 295.00 exceeds parent building a8c95904-bfb7-4e8e-875c-b3d9d2a93d84 top height 120.00; treating min_height/min_floor as 0 for the part
# Building part 58d52e14-98c6-31bd-8b86-0515df8cfa89 top height 295.00 exceeds parent building a8c95904-bfb7-4e8e-875c-b3d9d2a93d84 top height 120.00; treating min_height/min_floor as 0 for the part
# Building part d637d910-0011-3e03-b54a-56bd38b8e2d5 top height 295.00 exceeds parent building a8c95904-bfb7-4e8e-875c-b3d9d2a93d84 top height 120.00; treating min_height/min_floor as 0 for the part
# Building part f0d87666-f89a-34f2-bb47-d622c8497523 top height 247.00 exceeds parent building c0ef0dca-ffda-4263-a9a6-1ec8885f932b top height 110.20; treating min_height/min_floor as 0 for the part
# Building part ca0886a6-796a-3cb7-881e-c9a1365979cb top height 258.00 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Building part e0794e13-5180-3d3a-b98b-049a084c0414 top height 272.00 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Building part bbfba649-258b-3ebc-a65d-efecebbf1fdf top height 258.00 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Building part 441bd4a2-0fcb-3588-b9b4-f86982e8cfd3 top height 258.00 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Building part e3605ff8-cf48-3ebb-98c6-b4cb604cd6f6 top height 258.00 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Building part 27aad2b0-3501-3aa9-883f-21f393e2b52d top height 279.00 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Building part 9c4e2b48-5e8f-3c42-aed1-d572cb1f430c top height 279.00 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Building part 86d3b538-6dde-3c39-a79c-365da55fd705 top height 279.00 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Building part e29e1281-ee9f-3190-9248-6af69e0f4504 top height 279.00 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Building part f3f007eb-5b00-3307-a38d-0b7997f9c403 top height 313.79 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Building part 53e8d734-9bae-357f-8c16-d4eff8c68257 top height 316.00 exceeds parent building 7dc65ebf-6239-4260-bc93-8357539027e8 top height 75.00; treating min_height/min_floor as 0 for the part
# Building part 976f8e95-c654-3a62-a1c0-589c7fc91e53 top height 341.58 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Parsing buildings:  97%|█████████▋| 292/300 [00:00<00:00, 386.84it/s]Building part 04b47f98-3228-3ffe-b9d3-9e99008f6814 top height 341.58 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Building part ff05914d-a0f7-3ff2-8634-c14e5b3a8844 top height 364.00 exceeds parent building a8c95904-bfb7-4e8e-875c-b3d9d2a93d84 top height 120.00; treating min_height/min_floor as 0 for the part
# Building part 2b42e42f-4b7e-3911-9fa6-a8461689092a top height 359.58 exceeds parent building 7a20b9c9-0600-4b56-97cf-d789acbc8139 top height 180.00; treating min_height/min_floor as 0 for the part
# Building part 4ad97559-c0c7-3eab-b9cd-274fdb21f9c3 top height 409.00 exceeds parent building a8c95904-bfb7-4e8e-875c-b3d9d2a93d84 top height 120.00; treating min_height/min_floor as 0 for the part
# Building part 312580fc-8c27-3a14-a84c-54eb90b857c8 top height 431.80 exceeds parent building a8c95904-bfb7-4e8e-875c-b3d9d2a93d84 top height 120.00; treating min_height/min_floor as 0 for the part
# Building part a17f6317-a5f4-3c50-a3a4-896ebf841da2 top height 409.00 exceeds parent building a8c95904-bfb7-4e8e-875c-b3d9d2a93d84 top height 120.00; treating min_height/min_floor as 0 for the part
# Building part a128c1ac-0f26-396b-bbfc-29846ea57398 top height 409.00 exceeds parent building a8c95904-bfb7-4e8e-875c-b3d9d2a93d84 top height 120.00; treating min_height/min_floor as 0 for the part
# Building part ef5821ae-a713-3280-876d-8e472b335765 top height 409.00 exceeds parent building a8c95904-bfb7-4e8e-875c-b3d9d2a93d84 top height 120.00; treating min_height/min_floor as 0 for the part
# Parsing buildings: 100%|██████████| 300/300 [00:00<00:00, 386.90it/s]
# Scene generation complete!
#         mode  runtime_seconds  relative_to_lidar_osm
# 0  lidar-osm            2.905                   1.00
# 1   overture           25.668                   8.84
#         mode        height_source  building_count building_percentage
# 0  lidar-osm           osm:height             129              82.69%
# 1  lidar-osm      fallback:random              20              12.82%
# 2  lidar-osm  osm:building:levels               7               4.49%
# 3   overture      overture:height             460              96.23%
# 4   overture      fallback:random              11               2.30%
# 5   overture  overture:num_floors               7               1.46%
# LiDAR HAG raster exists : True

# %%
# Compare final building-height maps from the two modes.
lidar_map = np.load(Path(DATA_DIR_LIDAR_OSM) / "2D_Building_Height_Map.npy")
overture_map = np.load(Path(DATA_DIR_OVERTURE) / "2D_Building_Height_Map.npy")

diff = lidar_map.astype(float) - overture_map.astype(float)
building_mask = (lidar_map > 0) | (overture_map > 0)
mean_abs_diff = np.mean(np.abs(diff[building_mask])) if building_mask.any() else 0.0
max_abs_diff = np.max(np.abs(diff)) if diff.size else 0.0
lidar_hag_mask = rasterize_height_source_mask(
    lidar_height_source_records,
    "hag",
    lidar_map.shape,
    lidar_ground_bounds,
)
overture_explicit_height_mask = rasterize_height_source_mask(
    overture_height_source_records,
    "overture:height",
    lidar_map.shape,
    overture_ground_bounds,
)
building_pixel_count = int(np.count_nonzero(building_mask))
lidar_hag_not_overture_explicit_height_pixels = int(
        np.count_nonzero(lidar_hag_mask & ~overture_explicit_height_mask)
)
lidar_hag_not_overture_explicit_height_percent = (
        100.0
        * lidar_hag_not_overture_explicit_height_pixels
        / building_pixel_count
        if building_pixel_count
        else 0.0
)

comparison = pd.DataFrame(
    [
        ("same raster", np.array_equal(lidar_map, overture_map)),
        ("mean abs diff on building pixels (m)", round(float(mean_abs_diff), 3)),
        ("max abs diff (m)", round(float(max_abs_diff), 3)),
        (
            "LiDAR HAG pixels outside Overture explicit height (%)",
            round(float(lidar_hag_not_overture_explicit_height_percent), 3),
        ),
    ],
    columns=["check", "value"],
)
display(comparison)

height_vmax = max(float(lidar_map.max()), float(overture_map.max()), 1.0)
diff_abs_max = max(float(np.max(np.abs(diff))), 1.0) if diff.size else 1.0

fig, axs = plt.subplots(1, 3, figsize=(16, 5), constrained_layout=True)
height_im = axs[0].imshow(lidar_map, cmap="viridis", vmin=0, vmax=height_vmax)
axs[0].set_title("lidar-osm")
axs[1].imshow(overture_map, cmap="viridis", vmin=0, vmax=height_vmax)
axs[1].set_title("overture")
diff_im = axs[2].imshow(diff, cmap="coolwarm", vmin=-diff_abs_max, vmax=diff_abs_max)
axs[2].set_title("lidar-osm minus overture")
height_cbar = fig.colorbar(height_im, ax=axs[:2], fraction=0.046, pad=0.04)
height_cbar.set_label("Building height (m)")
diff_cbar = fig.colorbar(diff_im, ax=axs[2], fraction=0.046, pad=0.04)
diff_cbar.set_label("Height difference (m)")
for ax in axs:
    ax.axis("off")
plt.show()
# Out:
#                                                check   value
# 0                                        same raster   False
# 1               mean abs diff on building pixels (m)  18.403
# 2                                   max abs diff (m)   229.0
# 3  LiDAR HAG pixels outside Overture explicit hei...     0.0

# %%
lidar_osm_sionna_scene = scene.load_scene(DATA_DIR_LIDAR_OSM + "/scene.xml")
lidar_osm_sionna_scene.preview()
# Out:
# 2026-06-26 15:55:59 WARN  [HDRFilm] Monochrome mode enabled, setting film output pixel format to 'luminance' (was rgb).
# HBox(children=(Renderer(camera=PerspectiveCamera(aspect=1.31, children=(DirectionalLight(intensity=0.25, posit…

# %%
overture_sionna_scene = scene.load_scene(DATA_DIR_OVERTURE + "/scene.xml")
overture_sionna_scene.preview()
# Out:
# 2026-06-26 15:55:59 WARN  [HDRFilm] Monochrome mode enabled, setting film output pixel format to 'luminance' (was rgb).
# HBox(children=(Renderer(camera=PerspectiveCamera(aspect=1.31, children=(DirectionalLight(intensity=0.25, posit…
